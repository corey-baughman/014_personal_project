# %% [markdown]
# # Acquire Phase: New Business Location Predictor

# %% [markdown]
# ##### Using this code to test whether I can place a location from a google maps search into the proper U.S. Census tract.

# %%
import geopandas as gpd
from shapely.geometry import Point
import os

# Load census tract shapefile
tracts = gpd.read_file('tl_rd22_48_tract')

# Create point object
point = Point( -98.49460900270131, 29.4192557501264)

# Check if point is within a census tract
tract = tracts[tracts.contains(point)]

# Extract data from corresponding row in dataframe
if not tract.empty:
    tract_data = tract.iloc[0]
    print("Point is within census tract:", tract_data['NAME'])
else:
    print("Point is not within any census tract.")
# Out:
# Point is within census tract: 1101

# %%
# I input a sample point from google maps
# based on a map of census tract codes. At
# first it said the point was not in a census
# tract, but then I resversed the coordinates
# and it returned the correct tract code.
# NOTE: need to reverse order returned from 
# google maps. May be able to address this output
# at the Places API level.

# %%
tract
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID  NAME           NAMELSAD  MTFCC  \
# 1190      48      029  110100  48029110100  1101  Census Tract 1101  G5020
#
#      FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 1190        S  3428908   13720  +29.4261655  -098.4905264
#
#                                                geometry
# 1190  POLYGON ((-98.50167 29.42272, -98.50164 29.423...

# %%
tracts[tracts.TRACTCE == '192100']
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID  NAME           NAMELSAD  MTFCC  \
# 1893      48      029  192100  48029192100  1921  Census Tract 1921  G5020
#
#      FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 1893        S  2908611   63392  +29.4083684  -098.4936170
#
#                                                geometry
# 1893  POLYGON ((-98.50483 29.41450, -98.50458 29.414...

# %%
tracts.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME', 'NAMELSAD', 'MTFCC',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
tracts.head().T
# Out:
#                                                           0  \
# STATEFP                                                  48
# COUNTYFP                                                189
# TRACTCE                                              950200
# GEOID                                           48189950200
# NAME                                                   9502
# NAMELSAD                                  Census Tract 9502
# MTFCC                                                 G5020
# FUNCSTAT                                                  S
# ALAND                                               6306913
# AWATER                                                    0
# INTPTLAT                                        +34.2117433
# INTPTLON                                       -101.7172438
# geometry  POLYGON ((-101.735535 34.210512, -101.735528 3...
#
#                                                           1  \
# STATEFP                                                  48
# COUNTYFP                                                219
# TRACTCE                                              950400
# GEOID                                           48219950400
# NAME                                                   9504
# NAMELSAD                                  Census Tract 9504
# MTFCC                                                 G5020
# FUNCSTAT                                                  S
# ALAND                                              12691656
# AWATER                                                 5302
# INTPTLAT                                        +33.5889072
# INTPTLON                                       -102.3953070
# geometry  POLYGON ((-102.416159 33.569944, -102.416159 3...
#
#                                                           2  \
# STATEFP                                                  48
# COUNTYFP                                                219
# TRACTCE                                              950300
# GEOID                                           48219950300
# NAME                                                   9503
# NAMELSAD                                  Census Tract 9503
# MTFCC                                                 G5020
# FUNCSTAT                                                  S
# ALAND                                              12186639
# AWATER                                                    0
# INTPTLAT                                        +33.5869355
# INTPTLON                                       -102.3416971
# geometry  POLYGON ((-102.367625 33.583984, -102.367625 3...
#
#                                                           3  \
# STATEFP                                                  48
# COUNTYFP                                                219
# TRACTCE                                              950100
# GEOID                                           48219950100
# NAME                                                   9501
# NAMELSAD                                  Census Tract 9501
# MTFCC                                                 G5020
# FUNCSTAT                                                  S
# ALAND                                             214157569
# AWATER                                                    0
# INTPTLAT                                        +33.7715552
# INTPTLON                                       -102.1822653
# geometry  POLYGON ((-102.281924 33.724103, -102.281902 3...
#
#                                                           4
# STATEFP                                                  48
# COUNTYFP                                                219
# TRACTCE                                              950600
# GEOID                                           48219950600
# NAME                                                   9506
# NAMELSAD                                  Census Tract 9506
# MTFCC                                                 G5020
# FUNCSTAT                                                  S
# ALAND                                             358638163
# AWATER                                                    0
# INTPTLAT                                        +33.4659916
# INTPTLON                                       -102.1861385
# geometry  POLYGON ((-102.318263 33.41007, -102.315977 33...

# %%
tracts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 375 entries, 931 to 6569
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATEFP   375 non-null    object
#  1   COUNTYFP  375 non-null    object
#  2   TRACTCE   375 non-null    object
#  3   GEOID     375 non-null    object
#  4   NAME      375 non-null    object
#  5   NAMELSAD  375 non-null    object
#  6   MTFCC     375 non-null    object
#  7   FUNCSTAT  375 non-null    object
#  8   ALAND     375 non-null    int64
#  9   AWATER    375 non-null    int64
#  10  INTPTLAT  375 non-null    object
#  11  INTPTLON  375 non-null    object
#  12  geometry  375 non-null    geometry
# dtypes: geometry(1), int64(2), object(10)
# memory usage: 41.0+ KB

# %%
tracts.shape
# Out:
# (6896, 13)

# %%
# to filter tracts from all of Texas to Bexar
# County use COUNTYFP == '029'
tracts = tracts[(tracts.COUNTYFP == '029')]
tracts.shape
# Out:
# (375, 13)

# %%
#Let's open a census table for tracts in Bexar County
# and see what it looks like:
import numpy as np
import pandas as pd

sex = pd.read_csv('sex_and_age.csv')
sex
# Out:
#                    GEO_ID                                       NAME  \
# 0               Geography                       Geographic Area Name
# 1          0500000US48029                        Bexar County, Texas
# 2    1400000US48029110100     Census Tract 1101, Bexar County, Texas
# 3    1400000US48029110300     Census Tract 1103, Bexar County, Texas
# 4    1400000US48029110500     Census Tract 1105, Bexar County, Texas
# ..                    ...                                        ...
# 372  1400000US48029980002  Census Tract 9800.02, Bexar County, Texas
# 373  1400000US48029980003  Census Tract 9800.03, Bexar County, Texas
# 374  1400000US48029980004  Census Tract 9800.04, Bexar County, Texas
# 375  1400000US48029980005  Census Tract 9800.05, Bexar County, Texas
# 376  1400000US48029980100     Census Tract 9801, Bexar County, Texas
#
#                         S0101_C01_001E  \
# 0    Estimate!!Total!!Total population
# 1                              1978826
# 2                                 3153
# 3                                 3114
# 4                                 2430
# ..                                 ...
# 372                                  0
# 373                               1059
# 374                                  0
# 375                                  0
# 376                                943
#
#                                S0101_C01_001M  \
# 0    Margin of Error!!Total!!Total population
# 1                                       *****
# 2                                         504
# 3                                         638
# 4                                         392
# ..                                        ...
# 372                                        14
# 373                                       286
# 374                                        14
# 375                                        14
# 376                                       250
#
#                                        S0101_C01_001MA  \
# 0    Annotation of Margin of Error!!Total!!Total po...
# 1                                                *****
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
#
#                                      S0101_C01_001EA  \
# 0    Annotation of Estimate!!Total!!Total population
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 372                                              NaN
# 373                                              NaN
# 374                                              NaN
# 375                                              NaN
# 376                                              NaN
#
#                                         S0101_C01_002E  \
# 0    Estimate!!Total!!Total population!!AGE!!Under ...
# 1                                               139109
# 2                                                   70
# 3                                                  276
# 4                                                  540
# ..                                                 ...
# 372                                                  0
# 373                                                 84
# 374                                                  0
# 375                                                  0
# 376                                                 91
#
#                                        S0101_C01_002EA  \
# 0    Annotation of Estimate!!Total!!Total populatio...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
#
#                                         S0101_C01_002M  \
# 0    Margin of Error!!Total!!Total population!!AGE!...
# 1                                                   67
# 2                                                   74
# 3                                                  180
# 4                                                  207
# ..                                                 ...
# 372                                                 14
# 373                                                 31
# 374                                                 14
# 375                                                 14
# 376                                                 83
#
#                                        S0101_C01_002MA  ...  \
# 0    Annotation of Margin of Error!!Total!!Total po...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 372                                                NaN  ...
# 373                                                NaN  ...
# 374                                                NaN  ...
# 375                                                NaN  ...
# 376                                                NaN  ...
#
#                                        S0101_C06_036MA  \
# 0    Annotation of Margin of Error!!Percent Female!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         S0101_C06_037E  \
# 0    Estimate!!Percent Female!!Total population!!PE...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        S0101_C06_037EA  \
# 0    Annotation of Estimate!!Percent Female!!Total ...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         S0101_C06_037M  \
# 0    Margin of Error!!Percent Female!!Total populat...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        S0101_C06_037MA  \
# 0    Annotation of Margin of Error!!Percent Female!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         S0101_C06_038E  \
# 0    Estimate!!Percent Female!!Total population!!PE...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        S0101_C06_038EA  \
# 0    Annotation of Estimate!!Percent Female!!Total ...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         S0101_C06_038M  \
# 0    Margin of Error!!Percent Female!!Total populat...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        S0101_C06_038MA Unnamed: 914
# 0    Annotation of Margin of Error!!Percent Female!...          NaN
# 1                                                  (X)          NaN
# 2                                                  (X)          NaN
# 3                                                  (X)          NaN
# 4                                                  (X)          NaN
# ..                                                 ...          ...
# 372                                                (X)          NaN
# 373                                                (X)          NaN
# 374                                                (X)          NaN
# 375                                                (X)          NaN
# 376                                                (X)          NaN
#
# [377 rows x 915 columns]

# %%
# Ok, there's a lot of messiness here. 
# First, I'll lowercase all column names to make more pythonic
sex.columns = [col.lower() for col in sex.columns]
sex
# Out:
#                    geo_id                                       name  \
# 0               Geography                       Geographic Area Name
# 1          0500000US48029                        Bexar County, Texas
# 2    1400000US48029110100     Census Tract 1101, Bexar County, Texas
# 3    1400000US48029110300     Census Tract 1103, Bexar County, Texas
# 4    1400000US48029110500     Census Tract 1105, Bexar County, Texas
# ..                    ...                                        ...
# 372  1400000US48029980002  Census Tract 9800.02, Bexar County, Texas
# 373  1400000US48029980003  Census Tract 9800.03, Bexar County, Texas
# 374  1400000US48029980004  Census Tract 9800.04, Bexar County, Texas
# 375  1400000US48029980005  Census Tract 9800.05, Bexar County, Texas
# 376  1400000US48029980100     Census Tract 9801, Bexar County, Texas
#
#                         s0101_c01_001e  \
# 0    Estimate!!Total!!Total population
# 1                              1978826
# 2                                 3153
# 3                                 3114
# 4                                 2430
# ..                                 ...
# 372                                  0
# 373                               1059
# 374                                  0
# 375                                  0
# 376                                943
#
#                                s0101_c01_001m  \
# 0    Margin of Error!!Total!!Total population
# 1                                       *****
# 2                                         504
# 3                                         638
# 4                                         392
# ..                                        ...
# 372                                        14
# 373                                       286
# 374                                        14
# 375                                        14
# 376                                       250
#
#                                        s0101_c01_001ma  \
# 0    Annotation of Margin of Error!!Total!!Total po...
# 1                                                *****
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
#
#                                      s0101_c01_001ea  \
# 0    Annotation of Estimate!!Total!!Total population
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 372                                              NaN
# 373                                              NaN
# 374                                              NaN
# 375                                              NaN
# 376                                              NaN
#
#                                         s0101_c01_002e  \
# 0    Estimate!!Total!!Total population!!AGE!!Under ...
# 1                                               139109
# 2                                                   70
# 3                                                  276
# 4                                                  540
# ..                                                 ...
# 372                                                  0
# 373                                                 84
# 374                                                  0
# 375                                                  0
# 376                                                 91
#
#                                        s0101_c01_002ea  \
# 0    Annotation of Estimate!!Total!!Total populatio...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
#
#                                         s0101_c01_002m  \
# 0    Margin of Error!!Total!!Total population!!AGE!...
# 1                                                   67
# 2                                                   74
# 3                                                  180
# 4                                                  207
# ..                                                 ...
# 372                                                 14
# 373                                                 31
# 374                                                 14
# 375                                                 14
# 376                                                 83
#
#                                        s0101_c01_002ma  ...  \
# 0    Annotation of Margin of Error!!Total!!Total po...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 372                                                NaN  ...
# 373                                                NaN  ...
# 374                                                NaN  ...
# 375                                                NaN  ...
# 376                                                NaN  ...
#
#                                        s0101_c06_036ma  \
# 0    Annotation of Margin of Error!!Percent Female!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         s0101_c06_037e  \
# 0    Estimate!!Percent Female!!Total population!!PE...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        s0101_c06_037ea  \
# 0    Annotation of Estimate!!Percent Female!!Total ...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         s0101_c06_037m  \
# 0    Margin of Error!!Percent Female!!Total populat...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        s0101_c06_037ma  \
# 0    Annotation of Margin of Error!!Percent Female!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         s0101_c06_038e  \
# 0    Estimate!!Percent Female!!Total population!!PE...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        s0101_c06_038ea  \
# 0    Annotation of Estimate!!Percent Female!!Total ...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                         s0101_c06_038m  \
# 0    Margin of Error!!Percent Female!!Total populat...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
# 376                                                (X)
#
#                                        s0101_c06_038ma unnamed: 914
# 0    Annotation of Margin of Error!!Percent Female!...          NaN
# 1                                                  (X)          NaN
# 2                                                  (X)          NaN
# 3                                                  (X)          NaN
# 4                                                  (X)          NaN
# ..                                                 ...          ...
# 372                                                (X)          NaN
# 373                                                (X)          NaN
# 374                                                (X)          NaN
# 375                                                (X)          NaN
# 376                                                (X)          NaN
#
# [377 rows x 915 columns]

# %%
# That looks better

# %%
# Then, I think using the last 6 digits of the GEO_ID is the best
# way to get the census tract as it is more standardized than the name
# field. Then I'll drop the NAME column.
sex.dtypes
# Out:
# geo_id              object
# name                object
# s0101_c01_001e      object
# s0101_c01_001m      object
# s0101_c01_001ma     object
#                     ...
# s0101_c06_038e      object
# s0101_c06_038ea     object
# s0101_c06_038m      object
# s0101_c06_038ma     object
# unnamed: 914       float64
# Length: 915, dtype: object

# %%
# GEO_ID is an object, so:
sex.geo_id = sex.geo_id.str[-6:]
sex.head()
# Out:
#    geo_id                                    name  \
# 0  graphy                    Geographic Area Name
# 1  S48029                     Bexar County, Texas
# 2  110100  Census Tract 1101, Bexar County, Texas
# 3  110300  Census Tract 1103, Bexar County, Texas
# 4  110500  Census Tract 1105, Bexar County, Texas
#
#                       s0101_c01_001e  \
# 0  Estimate!!Total!!Total population
# 1                            1978826
# 2                               3153
# 3                               3114
# 4                               2430
#
#                              s0101_c01_001m  \
# 0  Margin of Error!!Total!!Total population
# 1                                     *****
# 2                                       504
# 3                                       638
# 4                                       392
#
#                                      s0101_c01_001ma  \
# 0  Annotation of Margin of Error!!Total!!Total po...
# 1                                              *****
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    s0101_c01_001ea  \
# 0  Annotation of Estimate!!Total!!Total population
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                                       s0101_c01_002e  \
# 0  Estimate!!Total!!Total population!!AGE!!Under ...
# 1                                             139109
# 2                                                 70
# 3                                                276
# 4                                                540
#
#                                      s0101_c01_002ea  \
# 0  Annotation of Estimate!!Total!!Total populatio...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       s0101_c01_002m  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                 67
# 2                                                 74
# 3                                                180
# 4                                                207
#
#                                      s0101_c01_002ma  ...  \
# 0  Annotation of Margin of Error!!Total!!Total po...  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                      s0101_c06_036ma  \
# 0  Annotation of Margin of Error!!Percent Female!...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       s0101_c06_037e  \
# 0  Estimate!!Percent Female!!Total population!!PE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      s0101_c06_037ea  \
# 0  Annotation of Estimate!!Percent Female!!Total ...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       s0101_c06_037m  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      s0101_c06_037ma  \
# 0  Annotation of Margin of Error!!Percent Female!...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       s0101_c06_038e  \
# 0  Estimate!!Percent Female!!Total population!!PE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      s0101_c06_038ea  \
# 0  Annotation of Estimate!!Percent Female!!Total ...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       s0101_c06_038m  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      s0101_c06_038ma unnamed: 914
# 0  Annotation of Margin of Error!!Percent Female!...          NaN
# 1                                                (X)          NaN
# 2                                                (X)          NaN
# 3                                                (X)          NaN
# 4                                                (X)          NaN
#
# [5 rows x 915 columns]

# %%
# that's better, but I accidentally truncated row 1 which is the
# human-readable column name. Let's look at the list of coded column names
# and see if there's any reason to keep them.
print(sex.columns.to_list())
# Out:
# ['geo_id', 'name', 's0101_c01_001e', 's0101_c01_001m', 's0101_c01_001ma', 's0101_c01_001ea', 's0101_c01_002e', 's0101_c01_002ea', 's0101_c01_002m', 's0101_c01_002ma', 's0101_c01_003e', 's0101_c01_003ea', 's0101_c01_003m', 's0101_c01_003ma', 's0101_c01_004e', 's0101_c01_004m', 's0101_c01_004ma', 's0101_c01_004ea', 's0101_c01_005e', 's0101_c01_005ea', 's0101_c01_005m', 's0101_c01_005ma', 's0101_c01_006e', 's0101_c01_006ea', 's0101_c01_006m', 's0101_c01_006ma', 's0101_c01_007e', 's0101_c01_007m', 's0101_c01_007ma', 's0101_c01_007ea', 's0101_c01_008e', 's0101_c01_008m', 's0101_c01_008ma', 's0101_c01_008ea', 's0101_c01_009e', 's0101_c01_009m', 's0101_c01_009ma', 's0101_c01_009ea', 's0101_c01_010e', 's0101_c01_010ea', 's0101_c01_010m', 's0101_c01_010ma', 's0101_c01_011e', 's0101_c01_011ea', 's0101_c01_011m', 's0101_c01_011ma', 's0101_c01_012e', 's0101_c01_012m', 's0101_c01_012ma', 's0101_c01_012ea', 's0101_c01_013e', 's0101_c01_013ea', 's0101_c01_013m', 's0101_c01_013ma', 's0101_c01_014e', 's0101_c01_014m', 's0101_c01_014ma', 's0101_c01_014ea', 's0101_c01_015e', 's0101_c01_015m', 's0101_c01_015ma', 's0101_c01_015ea', 's0101_c01_016e', 's0101_c01_016ea', 's0101_c01_016m', 's0101_c01_016ma', 's0101_c01_017e', 's0101_c01_017m', 's0101_c01_017ma', 's0101_c01_017ea', 's0101_c01_018e', 's0101_c01_018m', 's0101_c01_018ma', 's0101_c01_018ea', 's0101_c01_019e', 's0101_c01_019m', 's0101_c01_019ma', 's0101_c01_019ea', 's0101_c01_020e', 's0101_c01_020ea', 's0101_c01_020m', 's0101_c01_020ma', 's0101_c01_021e', 's0101_c01_021ea', 's0101_c01_021m', 's0101_c01_021ma', 's0101_c01_022e', 's0101_c01_022ea', 's0101_c01_022m', 's0101_c01_022ma', 's0101_c01_023e', 's0101_c01_023ea', 's0101_c01_023m', 's0101_c01_023ma', 's0101_c01_024e', 's0101_c01_024m', 's0101_c01_024ma', 's0101_c01_024ea', 's0101_c01_025e', 's0101_c01_025m', 's0101_c01_025ma', 's0101_c01_025ea', 's0101_c01_026e', 's0101_c01_026ea', 's0101_c01_026m', 's0101_c01_026ma', 's0101_c01_027e', 's0101_c01_027ea', 's0101_c01_027m', 's0101_c01_027ma', 's0101_c01_028e', 's0101_c01_028m', 's0101_c01_028ma', 's0101_c01_028ea', 's0101_c01_029e', 's0101_c01_029m', 's0101_c01_029ma', 's0101_c01_029ea', 's0101_c01_030e', 's0101_c01_030m', 's0101_c01_030ma', 's0101_c01_030ea', 's0101_c01_031e', 's0101_c01_031m', 's0101_c01_031ma', 's0101_c01_031ea', 's0101_c01_032e', 's0101_c01_032ea', 's0101_c01_032m', 's0101_c01_032ma', 's0101_c01_033e', 's0101_c01_033ea', 's0101_c01_033m', 's0101_c01_033ma', 's0101_c01_034e', 's0101_c01_034ea', 's0101_c01_034m', 's0101_c01_034ma', 's0101_c01_035e', 's0101_c01_035ea', 's0101_c01_035m', 's0101_c01_035ma', 's0101_c01_036e', 's0101_c01_036ea', 's0101_c01_036m', 's0101_c01_036ma', 's0101_c01_037e', 's0101_c01_037m', 's0101_c01_037ma', 's0101_c01_037ea', 's0101_c01_038e', 's0101_c01_038ea', 's0101_c01_038m', 's0101_c01_038ma', 's0101_c02_001e', 's0101_c02_001ea', 's0101_c02_001m', 's0101_c02_001ma', 's0101_c02_002e', 's0101_c02_002ea', 's0101_c02_002m', 's0101_c02_002ma', 's0101_c02_003e', 's0101_c02_003ea', 's0101_c02_003m', 's0101_c02_003ma', 's0101_c02_004e', 's0101_c02_004m', 's0101_c02_004ma', 's0101_c02_004ea', 's0101_c02_005e', 's0101_c02_005ea', 's0101_c02_005m', 's0101_c02_005ma', 's0101_c02_006e', 's0101_c02_006m', 's0101_c02_006ma', 's0101_c02_006ea', 's0101_c02_007e', 's0101_c02_007m', 's0101_c02_007ma', 's0101_c02_007ea', 's0101_c02_008e', 's0101_c02_008m', 's0101_c02_008ma', 's0101_c02_008ea', 's0101_c02_009e', 's0101_c02_009ea', 's0101_c02_009m', 's0101_c02_009ma', 's0101_c02_010e', 's0101_c02_010ea', 's0101_c02_010m', 's0101_c02_010ma', 's0101_c02_011e', 's0101_c02_011m', 's0101_c02_011ma', 's0101_c02_011ea', 's0101_c02_012e', 's0101_c02_012m', 's0101_c02_012ma', 's0101_c02_012ea', 's0101_c02_013e', 's0101_c02_013m', 's0101_c02_013ma', 's0101_c02_013ea', 's0101_c02_014e', 's0101_c02_014ea', 's0101_c02_014m', 's0101_c02_014ma', 's0101_c02_015e', 's0101_c02_015m', 's0101_c02_015ma', 's0101_c02_015ea', 's0101_c02_016e', 's0101_c02_016ea', 's0101_c02_016m', 's01 ...

# %%
# besides geo_id and name, those are actully pretty useless for the scope of this project
# I'll go ahead and drop that row and reassign row 1 as columns
# I'll go back and import the .csv using header=1 and skiprows=[0]
sex = pd.read_csv('sex_and_age.csv', skiprows=[0])
# I guess it does the skip first and then grabs header so just need the skiprows
sex
# Out:
#                 Geography                       Geographic Area Name  \
# 0          0500000US48029                        Bexar County, Texas
# 1    1400000US48029110100     Census Tract 1101, Bexar County, Texas
# 2    1400000US48029110300     Census Tract 1103, Bexar County, Texas
# 3    1400000US48029110500     Census Tract 1105, Bexar County, Texas
# 4    1400000US48029110600     Census Tract 1106, Bexar County, Texas
# ..                    ...                                        ...
# 371  1400000US48029980002  Census Tract 9800.02, Bexar County, Texas
# 372  1400000US48029980003  Census Tract 9800.03, Bexar County, Texas
# 373  1400000US48029980004  Census Tract 9800.04, Bexar County, Texas
# 374  1400000US48029980005  Census Tract 9800.05, Bexar County, Texas
# 375  1400000US48029980100     Census Tract 9801, Bexar County, Texas
#
#      Estimate!!Total!!Total population  \
# 0                              1978826
# 1                                 3153
# 2                                 3114
# 3                                 2430
# 4                                 5645
# ..                                 ...
# 371                                  0
# 372                               1059
# 373                                  0
# 374                                  0
# 375                                943
#
#     Margin of Error!!Total!!Total population  \
# 0                                      *****
# 1                                        504
# 2                                        638
# 3                                        392
# 4                                       1041
# ..                                       ...
# 371                                       14
# 372                                      286
# 373                                       14
# 374                                       14
# 375                                      250
#
#     Annotation of Margin of Error!!Total!!Total population  \
# 0                                                *****
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
#
#      Annotation of Estimate!!Total!!Total population  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 371                                              NaN
# 372                                              NaN
# 373                                              NaN
# 374                                              NaN
# 375                                              NaN
#
#      Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                               139109
# 1                                                   70
# 2                                                  276
# 3                                                  540
# 4                                                  207
# ..                                                 ...
# 371                                                  0
# 372                                                 84
# 373                                                  0
# 374                                                  0
# 375                                                 91
#
#      Annotation of Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
#
#      Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                   67
# 1                                                   74
# 2                                                  180
# 3                                                  207
# 4                                                  141
# ..                                                 ...
# 371                                                 14
# 372                                                 31
# 373                                                 14
# 374                                                 14
# 375                                                 83
#
#      Annotation of Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 371  ...
# 372  ...
# 373  ...
# 374  ...
# 375  ...
#
#      Annotation of Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Annotation of Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Annotation of Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Annotation of Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Annotation of Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
# 375                                                (X)
#
#      Unnamed: 914
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 371           NaN
# 372           NaN
# 373           NaN
# 374           NaN
# 375           NaN
#
# [376 rows x 915 columns]

# %%
# but now, row 0 is aggregate data for the county, this is not likely to be
# useful and may create confusion for modeling so will actually drop that at
# import as well. It is row 2 in the original .csv:
sex = pd.read_csv('sex_and_age.csv', skiprows=[0,2])

sex
# Out:
#                 Geography                       Geographic Area Name  \
# 0    1400000US48029110100     Census Tract 1101, Bexar County, Texas
# 1    1400000US48029110300     Census Tract 1103, Bexar County, Texas
# 2    1400000US48029110500     Census Tract 1105, Bexar County, Texas
# 3    1400000US48029110600     Census Tract 1106, Bexar County, Texas
# 4    1400000US48029110700     Census Tract 1107, Bexar County, Texas
# ..                    ...                                        ...
# 370  1400000US48029980002  Census Tract 9800.02, Bexar County, Texas
# 371  1400000US48029980003  Census Tract 9800.03, Bexar County, Texas
# 372  1400000US48029980004  Census Tract 9800.04, Bexar County, Texas
# 373  1400000US48029980005  Census Tract 9800.05, Bexar County, Texas
# 374  1400000US48029980100     Census Tract 9801, Bexar County, Texas
#
#      Estimate!!Total!!Total population  \
# 0                                 3153
# 1                                 3114
# 2                                 2430
# 3                                 5645
# 4                                 1079
# ..                                 ...
# 370                                  0
# 371                               1059
# 372                                  0
# 373                                  0
# 374                                943
#
#      Margin of Error!!Total!!Total population  \
# 0                                         504
# 1                                         638
# 2                                         392
# 3                                        1041
# 4                                         207
# ..                                        ...
# 370                                        14
# 371                                       286
# 372                                        14
# 373                                        14
# 374                                       250
#
#      Annotation of Margin of Error!!Total!!Total population  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 370                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
#
#      Annotation of Estimate!!Total!!Total population  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 370                                              NaN
# 371                                              NaN
# 372                                              NaN
# 373                                              NaN
# 374                                              NaN
#
#      Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                   70
# 1                                                  276
# 2                                                  540
# 3                                                  207
# 4                                                   43
# ..                                                 ...
# 370                                                  0
# 371                                                 84
# 372                                                  0
# 373                                                  0
# 374                                                 91
#
#      Annotation of Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 370                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
#
#      Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                   74
# 1                                                  180
# 2                                                  207
# 3                                                  141
# 4                                                   35
# ..                                                 ...
# 370                                                 14
# 371                                                 31
# 372                                                 14
# 373                                                 14
# 374                                                 83
#
#      Annotation of Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 370                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 370  ...
# 371  ...
# 372  ...
# 373  ...
# 374  ...
#
#      Annotation of Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Annotation of Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Annotation of Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Annotation of Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Annotation of Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Unnamed: 914
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 370           NaN
# 371           NaN
# 372           NaN
# 373           NaN
# 374           NaN
#
# [375 rows x 915 columns]

# %%
# boom, now take the last six of the Geography:
sex.Geography = sex.Geography.str[-6:]
sex.head()
# Out:
#   Geography                    Geographic Area Name  \
# 0    110100  Census Tract 1101, Bexar County, Texas
# 1    110300  Census Tract 1103, Bexar County, Texas
# 2    110500  Census Tract 1105, Bexar County, Texas
# 3    110600  Census Tract 1106, Bexar County, Texas
# 4    110700  Census Tract 1107, Bexar County, Texas
#
#    Estimate!!Total!!Total population  \
# 0                               3153
# 1                               3114
# 2                               2430
# 3                               5645
# 4                               1079
#
#    Margin of Error!!Total!!Total population  \
# 0                                       504
# 1                                       638
# 2                                       392
# 3                                      1041
# 4                                       207
#
#    Annotation of Margin of Error!!Total!!Total population  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annotation of Estimate!!Total!!Total population  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                 70
# 1                                                276
# 2                                                540
# 3                                                207
# 4                                                 43
#
#    Annotation of Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                 74
# 1                                                180
# 2                                                207
# 3                                                141
# 4                                                 35
#
#    Annotation of Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Annotation of Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Annotation of Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Annotation of Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Annotation of Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Annotation of Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Unnamed: 914
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 915 columns]

# %%
sex.columns.str.contains('Margin|Annotation')
# Out:
# array([False, False, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True,  True,  True, False])

# %%
# I'm going to drop most of these features, but there are so many that I will
# start by dropping all of the margin of error and annotation features
filtered_cols = sex.columns.str.contains('Margin|Annotation')
cols_to_drop = sex.columns[filtered_cols].to_list()
sex = sex.drop(columns=cols_to_drop)
sex

# def drop_cols(df):
#     for col in df.columns:
#         if
# Out:
#     Geography                       Geographic Area Name  \
# 0      110100     Census Tract 1101, Bexar County, Texas
# 1      110300     Census Tract 1103, Bexar County, Texas
# 2      110500     Census Tract 1105, Bexar County, Texas
# 3      110600     Census Tract 1106, Bexar County, Texas
# 4      110700     Census Tract 1107, Bexar County, Texas
# ..        ...                                        ...
# 370    980002  Census Tract 9800.02, Bexar County, Texas
# 371    980003  Census Tract 9800.03, Bexar County, Texas
# 372    980004  Census Tract 9800.04, Bexar County, Texas
# 373    980005  Census Tract 9800.05, Bexar County, Texas
# 374    980100     Census Tract 9801, Bexar County, Texas
#
#      Estimate!!Total!!Total population  \
# 0                                 3153
# 1                                 3114
# 2                                 2430
# 3                                 5645
# 4                                 1079
# ..                                 ...
# 370                                  0
# 371                               1059
# 372                                  0
# 373                                  0
# 374                                943
#
#      Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 0                                                   70
# 1                                                  276
# 2                                                  540
# 3                                                  207
# 4                                                   43
# ..                                                 ...
# 370                                                  0
# 371                                                 84
# 372                                                  0
# 373                                                  0
# 374                                                 91
#
#      Estimate!!Total!!Total population!!AGE!!5 to 9 years  \
# 0                                                   45
# 1                                                  267
# 2                                                  258
# 3                                                   86
# 4                                                   73
# ..                                                 ...
# 370                                                  0
# 371                                                 72
# 372                                                  0
# 373                                                  0
# 374                                                 63
#
#      Estimate!!Total!!Total population!!AGE!!10 to 14 years  \
# 0                                                   35
# 1                                                  128
# 2                                                  136
# 3                                                  114
# 4                                                   60
# ..                                                 ...
# 370                                                  0
# 371                                                 40
# 372                                                  0
# 373                                                  0
# 374                                                 84
#
#      Estimate!!Total!!Total population!!AGE!!15 to 19 years  \
# 0                                                   33
# 1                                                  209
# 2                                                  115
# 3                                                  256
# 4                                                   36
# ..                                                 ...
# 370                                                  0
# 371                                                225
# 372                                                  0
# 373                                                  0
# 374                                                169
#
#      Estimate!!Total!!Total population!!AGE!!20 to 24 years  \
# 0                                                  267
# 1                                                  170
# 2                                                  156
# 3                                                  476
# 4                                                   76
# ..                                                 ...
# 370                                                  0
# 371                                                244
# 372                                                  0
# 373                                                  0
# 374                                                232
#
#      Estimate!!Total!!Total population!!AGE!!25 to 29 years  \
# 0                                                  564
# 1                                                  208
# 2                                                  204
# 3                                                  726
# 4                                                   26
# ..                                                 ...
# 370                                                  0
# 371                                                150
# 372                                                  0
# 373                                                  0
# 374                                                 97
#
#      Estimate!!Total!!Total population!!AGE!!30 to 34 years  ...  \
# 0                                                  251       ...
# 1                                                  437       ...
# 2                                                  174       ...
# 3                                                  603       ...
# 4                                                   46       ...
# ..                                                 ...       ...
# 370                                                  0       ...
# 371                                                 77       ...
# 372                                                  0       ...
# 373                                                  0       ...
# 374                                                 68       ...
#
#      Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 0                                                 19.6
# 1                                                  8.5
# 2                                                 11.1
# 3                                                 25.1
# 4                                                 27.0
# ..                                                 ...
# 370                                                  -
# 371                                                0.0
# 372                                                  -
# 373                                                  -
# 374                                                2.9
#
#      Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 0                                                 10.1
# 1                                                  0.6
# 2                                                  4.7
# 3                                                 12.9
# 4                                                 14.0
# ..                                                 ...
# 370                                                  -
# 371                                                0.0
# 372                                                  -
# 373                                                  -
# 374                                                0.0
#
#      Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 370                                                (X)
# 371                                                (X)
# 372                                                (X)
# 373                                                (X)
# 374                                                (X)
#
#      Unnamed: 914
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 370           NaN
# 371           NaN
# 372           NaN
# 373           NaN
# 374           NaN
#
# [375 rows x 231 columns]

# %%
# ok, that dropped from 915 cols to 231. Now I'm just gonna look at the list
# for some features I may want.
cols = sex.columns.to_list()
cols
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Estimate!!Total!!Total population',
#  'Estimate!!Total!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Total!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Total!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Total!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Total!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Total!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Total!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Total!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Total!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Total!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Total!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Total!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Total!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Total!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Total!!Total population!!AGE!!70 to 74 years',
#  'Estimate!!Total!!Total population!!AGE!!75 to 79 years',
#  'Estimate!!Total!!Total population!!AGE!!80 to 84 years',
#  'Estimate!!Total!!Total population!!AGE!!85 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#  'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#  'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#  'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#  'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#  'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#  'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#  'Estimate!!Total!!Total population!!PERCENT ALLOCATED!!Sex',
#  'Estimate!!Total!!Total population!!PERCENT ALLOCATED!!Age',
#  'Estimate!!Percent!!Total population',
#  'Estimate!!Percent!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Percent!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Percent!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Percent!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Percent!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Percent!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Percent!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Percent!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Percent!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Percent!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Percent!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Percent!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Percent!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Percent!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Percent!!Total population!!AGE!!70 to 74 years',
#  'Estimate!!Percent!!Total population!!AGE!!75 to 79 years',
#  'Estimate!!Percent!!Total population!!AGE!!80 to 84 years',
#  'Estimate!!Percent!!Total population!!AGE!!85 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#  'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#  'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#  'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#  'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#  'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#  'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#  'Estimate!!Percent!!Total population!!PERCENT ALLOCATED!!Sex',
#  'Estimate!!Percent!!Total population!!PERCENT ALLOCATED!!Age',
#  'Estimate!!Male!!Total population',
#  'Estimate!!Male!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Male!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Male!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Male!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Male!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Male!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Male!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Male!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Male!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Male!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Male!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Male!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Male!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Male!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Male!!Total population!!AGE!!70 to 74 years',
#  'Estimate!!Male!!Total population!!AGE!!75 to 79 years',
#  'Estimate!!Male!!Total population!!AGE!!80 to 84 years',
#  'Estimate!!Male!!Total population!!AGE!!85 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#  'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#  'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#  'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#  'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#  'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#  'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#  'Estimate!!Male!!Total population!!PERCENT ALLOCATED!!Sex',
#  'Estimate!!Male!!Total population!!PERCENT ALLOCATED!!Age',
#  'Estimate!!Percent Male!!Total population',
#  'Estimate!!Percent Male!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!70 to 74 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!75 to 79 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!80 to 84 years',
#  'Estimate!!Percent Male!!Total population!!AGE!!85 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#  'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#  'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#  'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#  'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#  'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#  'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#  'Estimate!!Percent Male!!Total population!!PERCENT ALLOCATED!!Sex',
#  'Estimate!!Percent Male!!Total population!!PERCENT ALLOCATED!!Age',
#  'Estimate!!Female!!Total population',
#  'Estimate!!Female!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Female!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Female!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Female!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Female!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Female!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Female!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Female!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Female!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Female!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Female!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Female!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Female!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Female!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Female!!Total population!!AGE!!70 to 74 years',
#  'Estimate!!Female!!Total population!!AGE!!75 to 79 years',
#  'Estimate!!Female!!Total population!!AGE!!80 to 84 years',
#  'Estimate!!Female!!Total population!!AGE!!85 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#  'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#  'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#  'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#  'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#  'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#  'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#  'Estimate!!Female!!Total population!!PERCENT ALLOCATED!!Sex',
#  'Estimate!!Female!!Total population!!PERCENT ALLOCATED!!Age',
#  'Estimate!!Percent Female!!Total population',
#  'Estimate!!Percent Female!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!70 to 74 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!75 to 79 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!80 to 84 years',
#  'Estimate!!Percent Female!!Total population!!AGE!!85 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#  'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#  'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#  'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#  'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#  'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#  'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#  'Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex',
#  'Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age',
#  'Unnamed: 914']

# %%
sex_cols = ['Geography', 'Estimate!!Total!!Total population',
              'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
              'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
              'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio']
df = sex[sex_cols]
df.head()
# Out:
#   Geography  Estimate!!Total!!Total population  \
# 0    110100                               3153
# 1    110300                               3114
# 2    110500                               2430
# 3    110600                               5645
# 4    110700                               1079
#
#   Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 0                                              161.7
# 1                                               99.9
# 2                                              100.3
# 3                                              275.1
# 4                                              129.1
#
#   Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 0                                               29.0
# 1                                               13.0
# 2                                               25.4
# 3                                               15.0
# 4                                               49.2
#
#   Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio
# 0                                                6.4
# 1                                               43.4
# 2                                               89.8
# 3                                               11.6
# 4                                               35.8

# %%
df.columns = [col.lower() for col in df.columns]
df.columns = [col.replace('!!', '_') for col in df.columns]
df.columns = [col.replace('estimate_total_', '') for col in df.columns]
df.columns = [col.replace('summary indicators_', '') for col in df.columns]
df.columns = [col.replace('total population_', '') for col in df.columns]

# %%
df.head()
# Out:
#   geography  total population sex ratio (males per 100 females)  \
# 0    110100              3153                             161.7
# 1    110300              3114                              99.9
# 2    110500              2430                             100.3
# 3    110600              5645                             275.1
# 4    110700              1079                             129.1
#
#   old-age dependency ratio child dependency ratio
# 0                     29.0                    6.4
# 1                     13.0                   43.4
# 2                     25.4                   89.8
# 3                     15.0                   11.6
# 4                     49.2                   35.8

# %%
df.shape
# Out:
# (375, 5)

# %%
# ok, now apply similar steps to get the fields I need from
# the race and income tables.

# %%
race = pd.read_csv('race.csv', skiprows=[0,2])
race.head()
# Out:
#               Geography                    Geographic Area Name   !!Total:  \
# 0  1400000US48029110100  Census Tract 1101, Bexar County, Texas       3812
# 1  1400000US48029110300  Census Tract 1103, Bexar County, Texas       2401
# 2  1400000US48029110500  Census Tract 1105, Bexar County, Texas       2369
# 3  1400000US48029110600  Census Tract 1106, Bexar County, Texas       7284
# 4  1400000US48029110700  Census Tract 1107, Bexar County, Texas       1210
#
#    Annotation of  !!Total:   !!Total:!!Hispanic or Latino  \
# 0                      NaN                           1758
# 1                      NaN                           1589
# 2                      NaN                           1982
# 3                      NaN                           4763
# 4                      NaN                            933
#
#    Annotation of  !!Total:!!Hispanic or Latino  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#     !!Total:!!Not Hispanic or Latino:  \
# 0                                2054
# 1                                 812
# 2                                 387
# 3                                2521
# 4                                 277
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#     !!Total:!!Not Hispanic or Latino:!!Population of one race:  \
# 0                                               1940
# 1                                                750
# 2                                                369
# 3                                               2483
# 4                                                265
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:!!White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:!!White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unnamed: 148
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 149 columns]

# %%
race_cols = race.columns.to_list()
race_cols
# Out:
# ['Geography',
#  'Geographic Area Name',
#  ' !!Total:',
#  'Annotation of  !!Total:',
#  ' !!Total:!!Hispanic or Latino',
#  'Annotation of  !!Total:!!Hispanic or Latino',
#  ' !!Total:!!Not Hispanic or Latino:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:!!White alone',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!White alone',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Black or African American alone',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Black or African American alone',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:!!American Indian and Alaska Native alone',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!American Indian and Alaska Native alone',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Asian alone',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Asian alone',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Native Hawaiian and Other Pacific Islander alone',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Native Hawaiian and Other Pacific Islander alone',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Some Other Race alone',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!Some Other Race alone',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Black or African American',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Black or African American',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; American Indian and Alaska Native',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; American Indian and Alaska Native',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!White; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; American Indian and Alaska Native',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; American Indian and Alaska Native',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Black or African American; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!American Indian and Alaska Native; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!American Indian and Alaska Native; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!American Indian and Alaska Native; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!American Indian and Alaska Native; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of two races:!!Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; American Indian and Alaska Native',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; American Indian and Alaska Native',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Black or African American; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; American Indian and Alaska Native; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; American Indian and Alaska Native; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; American Indian and Alaska Native; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; American Indian and Alaska Native; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!White; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; American Indian and Alaska Native; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; American Indian and Alaska Native; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; American Indian and Alaska Native; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; American Indian and Alaska Native; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!American Indian and Alaska Native; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!American Indian and Alaska Native; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of three races:!!Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; American Indian and Alaska Native; Asian',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; American Indian and Alaska Native; Asian',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; American Indian and Alaska Native; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; American Indian and Alaska Native; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Black or African American; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; American Indian and Alaska Native; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; American Indian and Alaska Native; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!White; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of four races:!!American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; American Indian and Alaska Native; Asian; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; American Indian and Alaska Native; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; Black or African American; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!White; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of five races:!!Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:',
#  ' !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:!!White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Annotation of  !!Total:!!Not Hispanic or Latino:!!Population of two or more races:!!Population of six races:!!White; Black or African American; American Indian and Alaska Native; Asian; Native Hawaiian and Other Pacific Islander; Some Other Race',
#  'Unnamed: 148']

# %%
def get_race_data():
    '''
    This function takes in 'race.csv' from this
    repo (see README.md for how to get this file) and
    drops unnecessary columns as well as changing names
    to more pythonic and readable ones'''
    # read the file from the repo
    df = pd.read_csv('race.csv', skiprows=[0,2])
    # establish chosen columns from the DataFrame
    race_cols = ['Geography', ' !!Total:!!Hispanic or Latino']
    # redefine DataFrame as just the desired columns
    df = df[race_cols]
    # make the column names pythonic and readable
    df.columns = [col.lower() for col in df.columns]
    df.columns = [col.replace(' !!total:!!', 'total_') for col in df.columns]
    df.columns = [col.replace(' ', '_') for col in df.columns]
    
    # cut geography to the last six digits which are the census
    # tract id
    df.geography = df.geography.str[-6:]
    
    return df

# %%
# now add the income table

# %%
income = pd.read_csv('income.csv', skiprows=[0,2])
income.head()
# Out:
#               Geography                    Geographic Area Name  \
# 0  1400000US48029110100  Census Tract 1101, Bexar County, Texas
# 1  1400000US48029110300  Census Tract 1103, Bexar County, Texas
# 2  1400000US48029110500  Census Tract 1105, Bexar County, Texas
# 3  1400000US48029110600  Census Tract 1106, Bexar County, Texas
# 4  1400000US48029110700  Census Tract 1107, Bexar County, Texas
#
#    Estimate!!Households!!Total  Annotation of Estimate!!Households!!Total  \
# 0                         1840                                        NaN
# 1                         1409                                        NaN
# 2                          838                                        NaN
# 3                         1441                                        NaN
# 4                          534                                        NaN
#
#    Margin of Error!!Households!!Total  \
# 0                                 266
# 1                                 224
# 2                                 131
# 3                                 249
# 4                                  76
#
#    Annotation of Margin of Error!!Households!!Total  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Estimate!!Households!!Total!!Less than $10,000  \
# 0                                           10.4
# 1                                           10.5
# 2                                           48.0
# 3                                           22.8
# 4                                           30.7
#
#   Margin of Error!!Households!!Total!!Less than $10,000  \
# 0                                                5.4
# 1                                                4.7
# 2                                                9.6
# 3                                                7.4
# 4                                               11.6
#
#   Annotation of Margin of Error!!Households!!Total!!Less than $10,000  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Annotation of Estimate!!Households!!Total!!Less than $10,000  ...  \
# 0                                                NaN            ...
# 1                                                NaN            ...
# 2                                                NaN            ...
# 3                                                NaN            ...
# 4                                                NaN            ...
#
#   Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Annotation of Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# 0                                               32.1
# 1                                               32.2
# 2                                               31.6
# 3                                               26.7
# 4                                               18.3
#
#   Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Annotation of Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Unnamed: 258
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 259 columns]

# %%
income_cols = income.columns.to_list()

# %%
income_cols
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Estimate!!Households!!Total',
#  'Annotation of Estimate!!Households!!Total',
#  'Margin of Error!!Households!!Total',
#  'Annotation of Margin of Error!!Households!!Total',
#  'Estimate!!Households!!Total!!Less than $10,000',
#  'Margin of Error!!Households!!Total!!Less than $10,000',
#  'Annotation of Margin of Error!!Households!!Total!!Less than $10,000',
#  'Annotation of Estimate!!Households!!Total!!Less than $10,000',
#  'Estimate!!Households!!Total!!$10,000 to $14,999',
#  'Annotation of Estimate!!Households!!Total!!$10,000 to $14,999',
#  'Margin of Error!!Households!!Total!!$10,000 to $14,999',
#  'Annotation of Margin of Error!!Households!!Total!!$10,000 to $14,999',
#  'Estimate!!Households!!Total!!$15,000 to $24,999',
#  'Annotation of Estimate!!Households!!Total!!$15,000 to $24,999',
#  'Margin of Error!!Households!!Total!!$15,000 to $24,999',
#  'Annotation of Margin of Error!!Households!!Total!!$15,000 to $24,999',
#  'Estimate!!Households!!Total!!$25,000 to $34,999',
#  'Annotation of Estimate!!Households!!Total!!$25,000 to $34,999',
#  'Margin of Error!!Households!!Total!!$25,000 to $34,999',
#  'Annotation of Margin of Error!!Households!!Total!!$25,000 to $34,999',
#  'Estimate!!Households!!Total!!$35,000 to $49,999',
#  'Margin of Error!!Households!!Total!!$35,000 to $49,999',
#  'Annotation of Margin of Error!!Households!!Total!!$35,000 to $49,999',
#  'Annotation of Estimate!!Households!!Total!!$35,000 to $49,999',
#  'Estimate!!Households!!Total!!$50,000 to $74,999',
#  'Annotation of Estimate!!Households!!Total!!$50,000 to $74,999',
#  'Margin of Error!!Households!!Total!!$50,000 to $74,999',
#  'Annotation of Margin of Error!!Households!!Total!!$50,000 to $74,999',
#  'Estimate!!Households!!Total!!$75,000 to $99,999',
#  'Margin of Error!!Households!!Total!!$75,000 to $99,999',
#  'Annotation of Margin of Error!!Households!!Total!!$75,000 to $99,999',
#  'Annotation of Estimate!!Households!!Total!!$75,000 to $99,999',
#  'Estimate!!Households!!Total!!$100,000 to $149,999',
#  'Annotation of Estimate!!Households!!Total!!$100,000 to $149,999',
#  'Margin of Error!!Households!!Total!!$100,000 to $149,999',
#  'Annotation of Margin of Error!!Households!!Total!!$100,000 to $149,999',
#  'Estimate!!Households!!Total!!$150,000 to $199,999',
#  'Margin of Error!!Households!!Total!!$150,000 to $199,999',
#  'Annotation of Margin of Error!!Households!!Total!!$150,000 to $199,999',
#  'Annotation of Estimate!!Households!!Total!!$150,000 to $199,999',
#  'Estimate!!Households!!Total!!$200,000 or more',
#  'Margin of Error!!Households!!Total!!$200,000 or more',
#  'Annotation of Margin of Error!!Households!!Total!!$200,000 or more',
#  'Annotation of Estimate!!Households!!Total!!$200,000 or more',
#  'Estimate!!Households!!Median income (dollars)',
#  'Margin of Error!!Households!!Median income (dollars)',
#  'Annotation of Margin of Error!!Households!!Median income (dollars)',
#  'Annotation of Estimate!!Households!!Median income (dollars)',
#  'Estimate!!Households!!Mean income (dollars)',
#  'Margin of Error!!Households!!Mean income (dollars)',
#  'Annotation of Margin of Error!!Households!!Mean income (dollars)',
#  'Annotation of Estimate!!Households!!Mean income (dollars)',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Margin of Error!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Margin of Error!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Margin of Error!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Margin of Error!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Margin of Error!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Margin of Error!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Estimate!!Families!!Total',
#  'Annotation of Estimate!!Families!!Total',
#  'Margin of Error!!Families!!Total',
#  'Annotation of Margin of Error!!Families!!Total',
#  'Estimate!!Families!!Total!!Less than $10,000',
#  'Annotation of Estimate!!Families!!Total!!Less than $10,000',
#  'Margin of Error!!Families!!Total!!Less than $10,000',
#  'Annotation of Margin of Error!!Families!!Total!!Less than $10,000',
#  'Estimate!!Families!!Total!!$10,000 to $14,999',
#  'Annotation of Estimate!!Families!!Total!!$10,000 to $14,999',
#  'Margin of Error!!Families!!Total!!$10,000 to $14,999',
#  'Annotation of Margin of Error!!Families!!Total!!$10,000 to $14,999',
#  'Estimate!!Families!!Total!!$15,000 to $24,999',
#  'Annotation of Estimate!!Families!!Total!!$15,000 to $24,999',
#  'Margin of Error!!Families!!Total!!$15,000 to $24,999',
#  'Annotation of Margin of Error!!Families!!Total!!$15,000 to $24,999',
#  'Estimate!!Families!!Total!!$25,000 to $34,999',
#  'Annotation of Estimate!!Families!!Total!!$25,000 to $34,999',
#  'Margin of Error!!Families!!Total!!$25,000 to $34,999',
#  'Annotation of Margin of Error!!Families!!Total!!$25,000 to $34,999',
#  'Estimate!!Families!!Total!!$35,000 to $49,999',
#  'Annotation of Estimate!!Families!!Total!!$35,000 to $49,999',
#  'Margin of Error!!Families!!Total!!$35,000 to $49,999',
#  'Annotation of Margin of Error!!Families!!Total!!$35,000 to $49,999',
#  'Estimate!!Families!!Total!!$50,000 to $74,999',
#  'Annotation of Estimate!!Families!!Total!!$50,000 to $74,999',
#  'Margin of Error!!Families!!Total!!$50,000 to $74,999',
#  'Annotation of Margin of Error!!Families!!Total!!$50,000 to $74,999',
#  'Estimate!!Families!!Total!!$75,000 to $99,999',
#  'Margin of Error!!Families!!Total!!$75,000 to $99,999',
#  'Annotation of Margin of Error!!Families!!Total!!$75,000 to $99,999',
#  'Annotation of Estimate!!Families!!Total!!$75,000 to $99,999',
#  'Estimate!!Families!!Total!!$100,000 to $149,999',
#  'Margin of Error!!Families!!Total!!$100,000 to $149,999',
#  'Annotation of Margin of Error!!Families!!Total!!$100,000 to $149,999',
#  'Annotation of Estimate!!Families!!Total!!$100,000 to $149,999',
#  'Estimate!!Families!!Total!!$150,000 to $199,999',
#  'Margin of Error!!Families!!Total!!$150,000 to $199,999',
#  'Annotation of Margin of Error!!Families!!Total!!$150,000 to $199,999',
#  'Annotation of Estimate!!Families!!Total!!$150,000 to $199,999',
#  'Estimate!!Families!!Total!!$200,000 or more',
#  'Margin of Error!!Families!!Total!!$200,000 or more',
#  'Annotation of Margin of Error!!Families!!Total!!$200,000 or more',
#  'Annotation of Estimate!!Families!!Total!!$200,000 or more',
#  'Estimate!!Families!!Median income (dollars)',
#  'Margin of Error!!Families!!Median income (dollars)',
#  'Annotation of Margin of Error!!Families!!Median income (dollars)',
#  'Annotation of Estimate!!Families!!Median income (dollars)',
#  'Estimate!!Families!!Mean income (dollars)',
#  'Margin of Error!!Families!!Mean income (dollars)',
#  'Annotation of Margin of Error!!Families!!Mean income (dollars)',
#  'Annotation of Estimate!!Families!!Mean income (dollars)',
#  'Estimate!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Estimate!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Margin of Error!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Margin of Error!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Estimate!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Margin of Error!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Margin of Error!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Estimate!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Estimate!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Margin of Error!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Margin of Error!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Estimate!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Estimate!!Married-couple families!!Total',
#  'Margin of Error!!Married-couple families!!Total',
#  'Annotation of Margin of Error!!Married-couple families!!Total',
#  'Annotation of Estimate!!Married-couple families!!Total',
#  'Estimate!!Married-couple families!!Total!!Less than $10,000',
#  'Annotation of Estimate!!Married-couple families!!Total!!Less than $10,000',
#  'Margin of Error!!Married-couple families!!Total!!Less than $10,000',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!Less than $10,000',
#  'Estimate!!Married-couple families!!Total!!$10,000 to $14,999',
#  'Margin of Error!!Married-couple families!!Total!!$10,000 to $14,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$10,000 to $14,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$10,000 to $14,999',
#  'Estimate!!Married-couple families!!Total!!$15,000 to $24,999',
#  'Margin of Error!!Married-couple families!!Total!!$15,000 to $24,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$15,000 to $24,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$15,000 to $24,999',
#  'Estimate!!Married-couple families!!Total!!$25,000 to $34,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$25,000 to $34,999',
#  'Margin of Error!!Married-couple families!!Total!!$25,000 to $34,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$25,000 to $34,999',
#  'Estimate!!Married-couple families!!Total!!$35,000 to $49,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$35,000 to $49,999',
#  'Margin of Error!!Married-couple families!!Total!!$35,000 to $49,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$35,000 to $49,999',
#  'Estimate!!Married-couple families!!Total!!$50,000 to $74,999',
#  'Margin of Error!!Married-couple families!!Total!!$50,000 to $74,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$50,000 to $74,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$50,000 to $74,999',
#  'Estimate!!Married-couple families!!Total!!$75,000 to $99,999',
#  'Margin of Error!!Married-couple families!!Total!!$75,000 to $99,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$75,000 to $99,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$75,000 to $99,999',
#  'Estimate!!Married-couple families!!Total!!$100,000 to $149,999',
#  'Margin of Error!!Married-couple families!!Total!!$100,000 to $149,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$100,000 to $149,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$100,000 to $149,999',
#  'Estimate!!Married-couple families!!Total!!$150,000 to $199,999',
#  'Margin of Error!!Married-couple families!!Total!!$150,000 to $199,999',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$150,000 to $199,999',
#  'Annotation of Estimate!!Married-couple families!!Total!!$150,000 to $199,999',
#  'Estimate!!Married-couple families!!Total!!$200,000 or more',
#  'Annotation of Estimate!!Married-couple families!!Total!!$200,000 or more',
#  'Margin of Error!!Married-couple families!!Total!!$200,000 or more',
#  'Annotation of Margin of Error!!Married-couple families!!Total!!$200,000 or more',
#  'Estimate!!Married-couple families!!Median income (dollars)',
#  'Annotation of Estimate!!Married-couple families!!Median income (dollars)',
#  'Margin of Error!!Married-couple families!!Median income (dollars)',
#  'Annotation of Margin of Error!!Married-couple families!!Median income (dollars)',
#  'Estimate!!Married-couple families!!Mean income (dollars)',
#  'Margin of Error!!Married-couple families!!Mean income (dollars)',
#  'Annotation of Margin of Error!!Married-couple families!!Mean income (dollars)',
#  'Annotation of Estimate!!Married-couple families!!Mean income (dollars)',
#  'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Estimate!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Estimate!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Estimate!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Estimate!!Nonfamily households!!Total',
#  'Annotation of Estimate!!Nonfamily households!!Total',
#  'Margin of Error!!Nonfamily households!!Total',
#  'Annotation of Margin of Error!!Nonfamily households!!Total',
#  'Estimate!!Nonfamily households!!Total!!Less than $10,000',
#  'Annotation of Estimate!!Nonfamily households!!Total!!Less than $10,000',
#  'Margin of Error!!Nonfamily households!!Total!!Less than $10,000',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!Less than $10,000',
#  'Estimate!!Nonfamily households!!Total!!$10,000 to $14,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$10,000 to $14,999',
#  'Margin of Error!!Nonfamily households!!Total!!$10,000 to $14,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$10,000 to $14,999',
#  'Estimate!!Nonfamily households!!Total!!$15,000 to $24,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$15,000 to $24,999',
#  'Margin of Error!!Nonfamily households!!Total!!$15,000 to $24,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$15,000 to $24,999',
#  'Estimate!!Nonfamily households!!Total!!$25,000 to $34,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$25,000 to $34,999',
#  'Margin of Error!!Nonfamily households!!Total!!$25,000 to $34,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$25,000 to $34,999',
#  'Estimate!!Nonfamily households!!Total!!$35,000 to $49,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$35,000 to $49,999',
#  'Margin of Error!!Nonfamily households!!Total!!$35,000 to $49,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$35,000 to $49,999',
#  'Estimate!!Nonfamily households!!Total!!$50,000 to $74,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$50,000 to $74,999',
#  'Margin of Error!!Nonfamily households!!Total!!$50,000 to $74,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$50,000 to $74,999',
#  'Estimate!!Nonfamily households!!Total!!$75,000 to $99,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$75,000 to $99,999',
#  'Margin of Error!!Nonfamily households!!Total!!$75,000 to $99,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$75,000 to $99,999',
#  'Estimate!!Nonfamily households!!Total!!$100,000 to $149,999',
#  'Margin of Error!!Nonfamily households!!Total!!$100,000 to $149,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$100,000 to $149,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$100,000 to $149,999',
#  'Estimate!!Nonfamily households!!Total!!$150,000 to $199,999',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$150,000 to $199,999',
#  'Margin of Error!!Nonfamily households!!Total!!$150,000 to $199,999',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$150,000 to $199,999',
#  'Estimate!!Nonfamily households!!Total!!$200,000 or more',
#  'Margin of Error!!Nonfamily households!!Total!!$200,000 or more',
#  'Annotation of Margin of Error!!Nonfamily households!!Total!!$200,000 or more',
#  'Annotation of Estimate!!Nonfamily households!!Total!!$200,000 or more',
#  'Estimate!!Nonfamily households!!Median income (dollars)',
#  'Margin of Error!!Nonfamily households!!Median income (dollars)',
#  'Annotation of Margin of Error!!Nonfamily households!!Median income (dollars)',
#  'Annotation of Estimate!!Nonfamily households!!Median income (dollars)',
#  'Estimate!!Nonfamily households!!Mean income (dollars)',
#  'Annotation of Estimate!!Nonfamily households!!Mean income (dollars)',
#  'Margin of Error!!Nonfamily households!!Mean income (dollars)',
#  'Annotation of Margin of Error!!Nonfamily households!!Mean income (dollars)',
#  'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Annotation of Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Unnamed: 258']

# %%
def get_income_data():
    '''
    This function takes in 'income.csv' from this
    repo (see README.md for how to get this file) and
    drops unnecessary columns as well as changing names
    to more pythonic and readable ones'''
    # read the file from the repo
    df = pd.read_csv('income.csv', skiprows=[0,2])
    # establish chosen columns from the DataFrame
    income_cols = ['Geography', 'Estimate!!Households!!Median income (dollars)']
    # redefine DataFrame as just the desired columns
    df = df[income_cols]
    # make the column names pythonic and readable
    df.columns = [col.lower() for col in df.columns]
    df.columns = [col.replace('!!', '_') for col in df.columns]
    df.columns = [col.replace(' !!total:!!', 'total_') for col in df.columns]
    df.columns = [col.replace(' ', '_') for col in df.columns]
    df.columns = [col.replace('estimate_', '') for col in df.columns]
    # cut geography to the last six digits which are the census
    # tract id
    df.geography = df.geography.str[-6:]
    
    return df

# %%
tracts[tracts.TRACTCE == '970302']
# Out:
# Empty GeoDataFrame
# Columns: [STATEFP, COUNTYFP, TRACTCE, GEOID, NAME, NAMELSAD, MTFCC, FUNCSTAT, ALAND, AWATER, INTPTLAT, INTPTLON, geometry]
# Index: []

# %%
tracts
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  \
# 931       48      029  161600  48029161600     1616     Census Tract 1616
# 932       48      029  980003  48029980003  9800.03  Census Tract 9800.03
# 933       48      029  170101  48029170101  1701.01  Census Tract 1701.01
# 935       48      029  170200  48029170200     1702     Census Tract 1702
# 936       48      029  170300  48029170300     1703     Census Tract 1703
# ...      ...      ...     ...          ...      ...                   ...
# 6550      48      029  160100  48029160100     1601     Census Tract 1601
# 6566      48      029  160300  48029160300     1603     Census Tract 1603
# 6567      48      029  160400  48029160400     1604     Census Tract 1604
# 6568      48      029  160600  48029160600     1606     Census Tract 1606
# 6569      48      029  160701  48029160701  1607.01  Census Tract 1607.01
#
#       MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT      INTPTLON  \
# 931   G5020        S   6340742    7099  +29.3991515  -098.5974264
# 932   G5020        S  16145483    4426  +29.3724905  -098.6660170
# 933   G5020        S   1150840   45850  +29.4396522  -098.5198167
# 935   G5020        S   1730790       0  +29.4216623  -098.5208934
# 936   G5020        S   1860336  166812  +29.4218034  -098.5349833
# ...     ...      ...       ...     ...          ...           ...
# 6550  G5020        S   2492063  115558  +29.4088381  -098.5217808
# 6566  G5020        S   1764367       0  +29.3912299  -098.5263991
# 6567  G5020        S   2835670       0  +29.3903429  -098.5412402
# 6568  G5020        S   2200749       0  +29.4113725  -098.5537037
# 6569  G5020        S   2602283       0  +29.4063314  -098.5739064
#
#                                                geometry
# 931   POLYGON ((-98.64945 29.39736, -98.64932 29.397...
# 932   POLYGON ((-98.69015 29.38381, -98.69012 29.383...
# 933   POLYGON ((-98.52588 29.43696, -98.52584 29.437...
# 935   POLYGON ((-98.52844 29.41652, -98.52837 29.417...
# 936   POLYGON ((-98.54283 29.42725, -98.54277 29.427...
# ...                                                 ...
# 6550  POLYGON ((-98.53075 29.39924, -98.53072 29.399...
# 6566  POLYGON ((-98.53331 29.38458, -98.53320 29.385...
# 6567  POLYGON ((-98.55124 29.38443, -98.55123 29.384...
# 6568  POLYGON ((-98.56355 29.41304, -98.56338 29.414...
# 6569  POLYGON ((-98.58782 29.40756, -98.58782 29.407...
#
# [375 rows x 13 columns]
